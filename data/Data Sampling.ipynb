# %%
import pandas as pd
pd.options.display.max_columns= None
df1 = pd.read_csv("MetObjects.csv", low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-0e7c71289cbf> in <module>
#       1 import pandas as pd
#       2 pd.options.display.max_columns= None
# ----> 3 df1 = pd.read_csv("MetObjects.csv", low_memory=False)
#
# ...

# %%
print(df1)
# Out:
#        Object Number  Is Highlight  Is Public Domain  Object ID  \
# 0         1979.486.1         False             False          1
# 1         1980.264.5         False             False          2
# 2           67.265.9         False             False          3
# 3          67.265.10         False             False          4
# 4          67.265.11         False             False          5
# 5          67.265.12         False             False          6
# 6          67.265.13         False             False          7
# 7          67.265.14         False             False          8
# 8          67.265.15         False             False          9
# 9         1979.486.3         False             False         10
# 10        1979.486.2         False             False         11
# 11        1979.486.7         False             False         12
# 12        1979.486.4         False             False         13
# 13        1979.486.5         False             False         14
# ...

# %%
samples = df1.sample(n=1)
# google pandas exclude emptyy columns... exclude NaN

# %%
display(samples)
# Out:
#           Object Number  Is Highlight  Is Public Domain  Object ID  \
# 443213  2011.604.1.8275         False              True     721885
#
#                  Department     Object Name  \
# 443213  Greek and Roman Art  Kylix fragment
#
#                                                     Title       Culture  \
# 443213  Terracotta rim fragment of a kylix (drinking cup)  Greek, Attic
#
#                 Period Dynasty Reign Portfolio Artist Role Artist Prefix  \
# 443213  Late Classical     NaN   NaN       NaN         NaN           NaN
#
#        Artist Display Name Artist Display Bio Artist Suffix Artist Alpha Sort  \
# 443213                 NaN                NaN           NaN               NaN
#
#        Artist Nationality Artist Begin Date Artist End Date  \
# 443213                NaN               NaN             NaN
#
#                                Object Date  Object Begin Date  \
# 443213  first half of the 4th century B.C.               -530
#
# ...
